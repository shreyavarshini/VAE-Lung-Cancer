# %%
! git clone --recursive https://github.com/shreyavarshini/Cancer-Detection.git
# Out:
# Cloning into 'Cancer-Detection'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 18717 (delta 4), reused 26 (delta 2), pack-reused 18689
# Receiving objects: 100% (18717/18717), 318.63 MiB | 40.39 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Checking out files: 100% (18679/18679), done.

# %%
# imports and initializations
from __future__ import print_function
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.autograd import Variable
from torch.nn import functional as F
from torchvision import datasets, transforms, transforms, utils
from torchvision.utils import save_image
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# %%
! cd '/content/Cancer-Detection/data/train/'

# %%
# Arguments for the model
class Args:
  batch_size = 20
  epochs = 20
  no_cuda = False
  seed = 1
  log_interval = 10
  lr = 1e-1

args=Args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
device = torch.device("cuda" if args.cuda else "cpu")

# %%
# Dataset loader
def load_dataset( folder ):
    data_path = '/content/Cancer-Detection/data/' + folder
    transform = transforms.Compose([
    transforms.Resize(( 256, 256 ) ),
    transforms.ToTensor()
    ])
    dataset = datasets.ImageFolder( root=data_path, transform=transform )

    loader = torch.utils.data.DataLoader(
        dataset,
        batch_size=1,
        num_workers=5,
        shuffle=True
    )
    return loader

train_loader1 = load_dataset( 'train/benign_train' )
train_loader2 = load_dataset( 'train/malignant_train' )

test_loader1 = load_dataset( 'test/benign_test' )
test_loader2 = load_dataset( 'test/malignant_test' )

# %%
class VAE(nn.Module):
    def __init__(self, nc, ngf, ndf, latent_variable_size):
        super(VAE, self).__init__()

        self.nc = nc
        self.ngf = ngf
        self.ndf = ndf
        self.latent_variable_size = latent_variable_size

        # encoder
        self.e1 = nn.Conv2d(nc, ndf, 4, 2, 1)
        self.bn1 = nn.BatchNorm2d(ndf)

        self.e2 = nn.Conv2d(ndf, ndf*2, 4, 2, 1)
        self.bn2 = nn.BatchNorm2d(ndf*2)

        self.e3 = nn.Conv2d(ndf*2, ndf*4, 4, 2, 1)
        self.bn3 = nn.BatchNorm2d(ndf*4)

        self.e4 = nn.Conv2d(ndf*4, ndf*4, 4, 2, 1)
        self.bn4 = nn.BatchNorm2d(ndf*4)

        # changed 12 = 4
        self.e5 = nn.Conv2d(ndf*4, ndf*4, 12, 2, 1)
        self.bn5 = nn.BatchNorm2d(ndf*4)

        self.e6 = nn.Conv2d( ndf*8, ndf*8, 4, 2, 1)
        self.bn6 = nn.BatchNorm2d(ndf*8)

        #changed  8 = 4
        self.fc1 = nn.Linear(ndf*4*4*4, latent_variable_size)
        self.fc2 = nn.Linear(ndf*4*4*4, latent_variable_size)

        # decoder
        #changed 4 = 8
        self.d1 = nn.Linear(latent_variable_size, ngf*4*2*4*4)

        self.up1 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd1 = nn.ReplicationPad2d(1)
        #changed 4 = 8
        self.d2 = nn.Conv2d(ngf*4*2, ngf*4, 3, 1)
        self.bn6 = nn.BatchNorm2d(ngf*4, 1.e-3)

        self.up2 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd2 = nn.ReplicationPad2d(1)
        #changed 4 = 8, 2 = 4
        self.d3 = nn.Conv2d(ngf*4, ngf*2, 3, 1)
        self.bn7 = nn.BatchNorm2d(ngf*2, 1.e-3)

        self.up3 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd3 = nn.ReplicationPad2d(1)
        # changed 4 = 2, none = 2
        self.d4 = nn.Conv2d(ngf*2, ngf, 3, 1)
        self.bn8 = nn.BatchNorm2d(ngf, 1.e-3)
        # 5, 256, 32, 32

        self.up4 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd4 = nn.ReplicationPad2d(1)
        #changed ngf = ngf * 2
        self.d5 = nn.Conv2d(ngf, ngf, 3, 1)
        self.bn9 = nn.BatchNorm2d(ngf, 1.e-3)
        # 5, 256, 64, 64

        self.up6 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd6 = nn.ReplicationPad2d(1)
        self.d7 = nn.Conv2d(ngf, ngf, 3, 1)
        self.bn10 = nn.BatchNorm2d(ngf, 1.e-3)
        # 5, 256, 128, 128

        self.up5 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd5 = nn.ReplicationPad2d(1)
        self.d6 = nn.Conv2d(ngf, nc, 3, 1)

        self.leakyrelu = nn.LeakyReLU(0.2)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def encode(self, x):
        h1 = self.leakyrelu(self.bn1(self.e1(x)))
        h2 = self.leakyrelu(self.bn2(self.e2(h1)))
        h3 = self.leakyrelu(self.bn3(self.e3(h2)))
        h4 = self.leakyrelu(self.bn4(self.e4(h3)))
        h5 = self.leakyrelu(self.bn5(self.e5(h4)))
        #h6 = self.leakyrelu(self.bn6(self.e6(h5)))
        #changed 4 = 8
        h6 = h5.view(-1, self.ndf*4*4*4)

        return self.fc1(h6), self.fc2(h6)

    def reparametrize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        if args.cuda:
            eps = torch.cuda.FloatTensor(std.size()).normal_()
        else:
            eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps)
        return eps.mul(std).add_(mu)

    def decode(self, z):
        h1 = self.relu(self.d1(z))
        #changed 4 = 8
        h1 = h1.view(-1, self.ngf*4*2, 4, 4)
        h2 = self.leakyrelu(self.bn6(self.d2(self.pd1(self.up1(h1)))))
        h3 = self.leakyrelu(self.bn7(self.d3(self.pd2(self.up2(h2)))))
        h4 = self.leakyrelu(self.bn8(self.d4(self.pd3(self.up3(h3)))))
        h5 = self.leakyrelu(self.bn9(self.d5(self.pd4(self.up4(h4)))))
        h6 = self.leakyrelu(self.bn10(self.d7(self.pd6(self.up6(h5)))))
        #changed h6 = h5
        return self.sigmoid(self.d6(self.pd5(self.up5(h6))))

    def get_latent_var(self, x):
        mu, logvar = self.encode(x.view(-1, self.nc, self.ndf, self.ngf))
        z = self.reparametrize(mu, logvar)
        return z

    def forward(self, x):
        mu, logvar = self.encode(x.view(-1, self.nc, self.ndf, self.ngf))
        z = self.reparametrize(mu, logvar)
        res = self.decode(z)
        return res, mu, logvar


model = VAE(nc=3, ngf=256, ndf=256, latent_variable_size=200)

if args.cuda:
    model.cuda()

reconstruction_function = nn.BCELoss()
reconstruction_function.size_average = False
def loss_function(recon_x, x, mu, logvar):
    BCE = reconstruction_function(recon_x, x)
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD_element = mu.pow(2).add_(logvar.exp()).mul_(-1).add_(1).add_(logvar)
    KLD = torch.sum(KLD_element).mul_(-0.5)

    return BCE + KLD


optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader1):
        data = Variable(data)
        data = data.to(device)
        # update the gradients to zero
        optimizer.zero_grad()

        # forward pass
        recon_batch, mu, logvar = model(data)

        # reconstruction loss + kl divergence loss
        loss = loss_function(recon_batch, data, mu, logvar)
        
         # backward pass
        loss.backward()
        train_loss += loss.item()

        # update the weights
        optimizer.step()

        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader1.dataset),
                100. * batch_idx / len(train_loader1),
                loss.item() / len(data)))

    print('====> Epoch: {} Average loss: {:.4f}'.format(
          epoch, train_loss / len(train_loader1.dataset)))


def test(epoch):
    # set the evaluation mode
    model.eval()

    # test loss for the data
    test_loss = 0

    with torch.no_grad():
        for i, (data, _) in enumerate(test_loader1):
            data = Variable(data)
            data = data.to(device)

            # forward pass
            recon_batch, mu, logvar = model(data)
            img = recon_batch[0].cpu().permute(1, 2, 0)
            plt.figure()
            _ = plt.imshow(img)
            name = '/content/Cancer-Detection/Generated_data/Malignant/image_' + str(i) + ".png" 
            plt.savefig(name)

            # total loss
            test_loss += loss_function(recon_batch, data, mu, logvar).item()

    test_loss /= len(test_loader1.dataset)
    print('====> Test set loss: {:.4f}'.format(test_loss))

if __name__ == "__main__":
    for epoch in range(1, args.epochs + 1):
        train(epoch)
        test(epoch)
        with torch.no_grad():
            sample = torch.randn(1, 200).to(device)
            sample = Variable(sample )
            sample = model.decode(sample).cpu()
            img = sample[0].permute(1, 2, 0)
            plt.figure()
            plt.imshow(img )
            plt.show()
    with torch.no_grad():
      for i in range(1000):
        sample = torch.randn(1, 200).to(device)
        sample = Variable(sample)
        sample = model.decode(sample).cpu()
        img = sample[0].permute(1, 2, 0)
        
        plt.figure()
        _ = plt.imshow(img)
        name = '/content/Cancer-Detection/Generated_data/Malignant/image_' + str(i) + ".png" 
        plt.savefig(name)
    
    ! zip -r "/content/drive/My Drive/images.Malignant_zip" "/content/Cancer-Detection/Generated_data/Malignant/"

# %%
# !ps -aux|grep python
# Out:
# root          18  0.1  0.7 403932 100536 ?       Sl   15:05   0:03 /usr/bin/python2 /usr/local/bin/jupyter-notebook --ip="172.28.0.2" --port=9000 --FileContentsManager.root_dir="/" --MappingKernelManager.root_dir="/content"
# root         122 69.6 27.0 33165612 3609652 ?    Ssl  15:05  25:47 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-66082227-05ee-4f47-aae6-e39c853b3de4.json
# root         584  0.0  0.0  39192  6388 ?        S    15:42   0:00 /bin/bash -c ps -aux|grep python
# root         586  0.0  0.0  16132   744 ?        R    15:42   0:00 grep python

# %%
# !kill -9 122

# %%
! zip -r "/content/images_Benign2.zip" "/content/Cancer-Detection/Generated_data/Benign2/"
# Out:
#   adding: content/Cancer-Detection/Generated_data/Benign2/ (stored 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_140.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_474.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_412.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_594.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_491.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_898.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_503.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_401.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_38.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_245.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_858.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_980.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_865.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_680.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_89.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_886.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1008.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_453.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_778.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_127.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_488.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_964.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_259.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_300.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_51.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_584.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_693.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_486.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_588.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_393.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_643.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_736.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_302.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_704.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_133.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_944.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_84.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_597.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_744.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_418.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_894.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_941.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_269.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_399.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_159.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_951.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_395.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_88.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_340.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_805.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_182.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_914.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_20.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_468.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_458.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_449.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_390.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_620.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_79.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_440.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_881.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_465.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_979.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_891.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_520.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_679.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_288.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_694.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_655.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_383.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_304.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_264.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_726.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_244.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_180.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_550.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1000.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_797.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_52.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_660.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_525.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_351.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_40.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_632.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_473.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_519.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_537.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_53.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_529.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_347.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_651.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_260.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_429.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_687.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_841.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_740.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_184.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_640.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_619.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_727.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_409.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_56.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_364.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_402.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_186.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_470.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_188.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_314.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_397.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_871.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_540.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_147.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_559.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_902.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_297.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_87.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_912.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_838.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_649.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_981.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_114.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_664.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_404.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_794.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_860.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_700.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_716.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_952.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_448.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_2.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_790.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_729.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_439.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_228.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_512.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_993.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_464.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_534.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_555.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_433.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_686.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_527.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_524.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_125.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_954.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_827.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1010.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_889.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_59.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_447.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_317.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_521.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_284.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_222.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_698.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_240.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_809.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_246.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_369.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_499.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_609.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_334.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_572.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_76.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_396.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_306.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_367.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_175.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_292.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_335.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_320.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_795.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_14.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_16.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_746.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_835.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_972.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_762.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_472.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_4.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_266.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_530.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_166.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_630.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1012.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_280.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_218.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_67.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_907.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_444.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_752.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_319.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_18.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_400.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_921.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_3.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_98.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_296.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_735.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_148.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_420.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_371.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_198.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_63.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_171.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_119.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_737.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_480.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_349.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_267.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_242.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1002.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_551.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_61.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_451.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_342.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_814.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_791.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_759.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_377.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_927.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_265.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_658.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_496.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_761.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_997.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_769.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_774.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_498.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_73.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_345.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_771.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_618.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_598.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_258.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_905.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_105.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_423.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_966.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_32.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_755.png (deflated 3%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_600.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_15.png (deflated 3%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_837.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_141.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_599.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_379.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_539.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_518.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_556.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_799.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_50.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_251.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_732.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_507.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_321.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_946.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_26.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_31.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_893.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_621.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_592.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_887.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_117.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_460.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_208.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_357.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_331.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_373.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_821.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_645.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_646.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_758.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_848.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_563.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_743.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_303.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_47.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_478.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_261.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_690.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_354.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_535.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_276.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_928.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_756.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_792.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_948.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_932.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_149.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_826.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_585.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_29.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_587.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_876.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_513.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_97.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_187.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_811.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_777.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_718.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_279.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_158.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_532.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_573.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_41.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_65.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_115.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_111.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_940.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_213.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_57.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_452.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_92.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_120.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_719.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_553.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_654.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_227.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_734.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_709.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_462.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_192.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_800.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_151.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_189.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_757.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_840.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_904.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_12.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_665.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_275.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_21.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_95.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_359.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_436.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_248.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_943.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_315.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_386.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1009.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_586.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_807.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_504.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_872.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_576.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_74.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_430.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_282.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_509.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_212.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_72.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_924.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_39.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_616.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_281.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_494.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_933.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_622.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_508.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_455.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_614.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_544.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_831.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_81.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_307.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_10.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_624.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_330.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_708.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_818.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_804.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_394.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_569.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_78.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_854.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_102.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_191.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_339.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_629.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_751.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_583.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_337.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_294.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_961.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_541.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_138.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_216.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_247.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_183.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_672.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_121.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_950.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_86.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_290.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_221.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_753.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_717.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_909.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_23.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_252.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_668.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_987.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_283.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_976.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_301.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_193.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_116.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_896.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_238.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_165.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_476.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_154.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_442.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_108.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_816.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_918.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_153.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_457.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1003.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_803.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_70.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_775.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_787.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_994.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_830.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_975.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_851.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_13.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_511.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_579.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_365.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_500.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_839.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_603.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_780.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_424.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_270.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_225.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_203.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_999.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_181.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_313.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_955.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_834.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_441.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_414.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_636.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_538.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_77.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_650.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_706.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_962.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_428.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_888.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_788.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_782.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_163.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_162.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_763.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_659.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_903.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_843.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_343.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_356.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_581.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_937.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_875.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_626.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_574.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_642.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_325.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_715.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_606.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_179.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_311.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_406.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_647.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_767.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_783.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_336.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_352.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_254.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_233.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_910.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_332.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_391.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_973.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_913.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_866.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_637.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_177.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_90.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_19.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_701.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_562.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_112.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_326.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_641.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_361.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_223.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_443.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_917.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_683.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_403.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_195.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_316.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_939.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_922.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_656.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_533.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_965.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_982.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_161.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_985.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_150.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_842.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_48.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_938.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_219.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_96.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_130.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_230.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_801.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_741.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_765.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_684.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_113.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_273.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_703.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_328.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_199.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_607.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_229.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_545.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_575.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_868.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_874.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_362.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_445.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_93.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_209.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_808.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_341.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_738.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_863.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1005.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_410.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_671.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_466.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_287.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_176.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_956.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_820.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_959.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_925.png (deflated 1%)
# ...
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_998.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_766.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_68.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_926.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_144.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_169.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_487.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_634.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_822.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_388.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_156.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_107.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_796.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_970.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_853.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_427.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_145.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_438.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_255.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_864.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_370.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_930.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_725.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_463.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_324.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_747.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_582.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_815.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_211.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_456.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_434.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_250.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_590.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_461.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_168.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_143.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_900.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_201.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_214.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_867.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_408.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_733.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_892.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_936.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_131.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_207.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_554.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_745.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_419.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_908.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_170.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_549.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_695.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1001.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_322.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_739.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_353.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_446.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_34.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_382.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_696.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_580.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_298.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_699.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_749.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_271.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_380.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_764.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_492.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_490.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_344.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_849.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_243.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_510.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_612.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_768.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_862.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_309.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_880.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_1007.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_99.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_350.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_338.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_516.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_407.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_810.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_190.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_829.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_426.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_160.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_475.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_83.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_784.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_552.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_49.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_571.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_884.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_852.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_850.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_628.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_139.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_224.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_27.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_785.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_28.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_291.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_605.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_194.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_593.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_0.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_705.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_378.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_608.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_286.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_681.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_293.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_712.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_897.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_502.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_157.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_859.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_772.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_30.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_861.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_416.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_310.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_855.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_652.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_644.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_355.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_54.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_968.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_241.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_467.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_754.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_136.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_613.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_435.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_920.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_173.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_798.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_484.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_770.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_501.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_103.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_374.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_577.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_46.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_667.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_707.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_256.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_69.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_146.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_272.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_564.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_495.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_595.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_536.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_91.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_155.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_591.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_989.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_104.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_469.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_773.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_974.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_178.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_217.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_823.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_164.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_691.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_505.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_11.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_776.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_779.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_557.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_204.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_638.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_253.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_94.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_635.png (deflated 2%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_196.png (deflated 0%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_327.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_781.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_969.png (deflated 1%)
#   adding: content/Cancer-Detection/Generated_data/Benign2/image_9.png (deflated 1%)
